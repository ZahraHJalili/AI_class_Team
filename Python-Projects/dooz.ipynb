# %%
BOARD = [["  " for h in range(3)] for h in range(3)]

for row in BOARD:
  print(row)
# Out:
# ['  ', '  ', '  ']
# ['  ', '  ', '  ']
# ['  ', '  ', '  ']

# %%
board = [["  " for _ in range(3)] for _ in range(3)]

board[1][1] = 'X'

for row in board:
  print(row)
# Out:
# ['  ', '  ', '  ']
# ['  ', 'X', '  ']
# ['  ', '  ', '  ']

# %%
def print_board(board):
  i = 0
  for row in board:
    print(f'{i}. | '.join(row))
    print("-" * 9)
    i = i+1

board = [["  " for _ in range(3)] for _ in range(3)]

board[1][1] = 'X'
print_board(board)
# Out:
#   0. |   0. |
# ---------
#   1. | X1. |
# ---------
#   2. |   2. |
# ---------

# %%
def print_board(board):
    for row in board:
        print(" | ".join(row))
        print("-" * 10)

def rule(board, player):
    for row in board:
        if all(s == player for s in row):
            return True
    
    #if board[2][0] == board[2][1] == board[2][2] or board[1][0] == board[1][1] == board[1][2] or board[0][0] == board[0][1] == board[0][2]:
    #    return
# Out:
#   |   |
# ----------
#   |   |
# ----------
#   |   |
# ----------
#   |   | X
# ----------
#   |   |
# ----------
#   |   |
# ----------
# O |   | X
# ----------
#   |   |
# ----------
#   |   |
# ----------
# O | X | X
# ----------
#   |   |
# ----------
#   |   |
# ----------
# O | X | X
# ----------
#   | O |
# ----------
#   |   |
# ----------
# O | X | X
# ----------
#   | O | X
# ----------
#   |   |
# ----------
# O | X | X
# ----------
#   | O | X
# ----------
#   |   | O
# ----------
# بازیکن O برنده شد! 🎉

# %%
board = [["  " for _ in range(3)] for _ in range(3)]
def print_board(board):
    for row in board:
        print(f" | ".join(row))
        print("-" * 10)

def check_winner(board, player):
    
    for row in board:
        if all(s == player for s in row):
            return True
    
    for col in range(3):
        if all(board[row][col] == player for row in range(3)):
            return True
    
    if all(board[i][i] == player for i in range(3)) or all(board[i][2 - i] == player for i in range(3)):
        return True
    return False

board = [[" " for _ in range(3)] for _ in range(3)]
player = "X"

for turn in range(9):
    print_board(board)
    row = int(input(f"بازیکن {player}، شماره ردیف (0-2): "))
    col = int(input(f"بازیکن {player}، شماره ستون (0-2): "))

    if board[row][col] == " ":
        board[row][col] = player
        if check_winner(board, player):
            print_board(board)
            print(f"بازیکن {player} برنده شد! 🎉")
            break
        player = "O" if player == "X" else "X"
    else:
        print("این خانه پره! دوباره انتخاب کن.")

else:
    print("بازی مساوی شد! 😐")
# Out:
#   |   |
# ----------
#   |   |
# ----------
#   |   |
# ----------
#   |   |
# ----------
#   | X |
# ----------
#   |   |
# ----------
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[2], line 27
#      25 print_board(board)
#      26 row = int(input(f"بازیکن {player}، شماره ردیف (0-2): "))
# ---> 27 col = int(input(f"بازیکن {player}، شماره ستون (0-2): "))
#      29 if board[row][col] == " ":
#      30     board[row][col] = player
#
# ValueError: invalid literal for int() with base 10: ''
